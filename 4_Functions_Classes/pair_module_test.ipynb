# %% [markdown]
# # import module_name

# %%
import module_test

# %%
module_test.namecity("liang","mica","China","Female")
# Out:
# {'full_name': 'liang mica', 'place': 'China', 'M_or_W': 'Female'}

# %%
module_test.mfunc(["andy","angle","rose","sofia"])
# Out:
# Andy is my best friend!
# Angle is my best friend!
# Rose is my best friend!
# Sofia is my best friend!

# %%
module_test.my_function(["apple","banana","cherry"])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# # import function name

# %%
from module_test import my_function

# %%
fruits=["apple","banana","cherry"]
my_function(fruits)
# Out:
# apple
# banana
# cherry

# %%
from module_test import mfunc

# %%
my_friends=["andy","angle","rose","sofia"]
mfunc(my_friends)
# Out:
# Andy is my best friend!
# Angle is my best friend!
# Rose is my best friend!
# Sofia is my best friend!

# %% [markdown]
# # import function as another short name

# %%
from module_test import mfunc as mf

# %%
mf(["andy","angle","rose","sofia"])
# Out:
# Andy is my best friend!
# Angle is my best friend!
# Rose is my best friend!
# Sofia is my best friend!

# %% [markdown]
# # import all function in once

# %%
from module_test import *

# %%
subjects=['data_science','mathmatics','english']
course(subjects)
# Out:
# data_science
# mathmatics
# english
