# %% [markdown]
# # W4_Function_Class

# %%
def my_function():
    print("Hello from a function")

# %%
my_function()
# Out:
# Hello from a function

# %%
def my_function(name):
    print(name+"! Hello from a function")

# %%
my_function("Mica")
# Out:
# Mica! Hello from a function

# %%
my_function("Sara")
# Out:
# Sara! Hello from a function

# %% [markdown]
# # Function-position arguments

# %%
def nameAge(name,age):
    print("Hi,I am "+name)
    print("My age is "+str(age))

# %%
nameAge("Mica",28)
# Out:
# Hi,I am Mica
# My age is 28

# %%
# must follow the order
nameAge("28","mica")
# Out:
# Hi,I am 28
# My age is mica

# %% [markdown]
# # Function-keywords arguments

# %%
def nameAge(name,age):
    print("Hi,I am "+name)
    print("My age is "+str(age))

# %%
# 如果输入是给参数赋值，那就不需要按位置输入.
nameAge(name="Mica",age=20)
# Out:
# Hi,I am Mica
# My age is 20

# %%
nameAge(age=24,name="Sara")
# Out:
# Hi,I am Sara
# My age is 24

# %% [markdown]
# # Function-Default value

# %%
def nameAge(name,age=27):
    print("Hi,I am "+name)
    print("My age is "+str(age))

# %%
nameAge("Mica")
# Out:
# Hi,I am Mica
# My age is 27

# %%
nameAge(name="Mica")
# Out:
# Hi,I am Mica
# My age is 27

# %%
nameAge(name="Mica",age=20)
# Out:
# Hi,I am Mica
# My age is 20

# %% [markdown]
# # Return values

# %%
nameAge("Sara",30)
# Out:
# Hi,I am Sara
# My age is 30

# %%
nameAge('30',"Rose")
# Out:
# Hi,I am 30
# My age is Rose

# %%
def get_formatted_name(first_name,last_name):
    """return a full name,neatly formatted."""
    full_name=first_name + ' '+ last_name
    return full_name.title()

# %%
musician=get_formatted_name("LIANG","Mica")
print(musician)
# Out:
# Liang Mica

# %%
def info(first_name,last_name,age,hobby):
    full_name=first_name + " " + last_name
    return("my full name is " + full_name+" ,my age is "+str(age)+" ,i like "+hobby)

# %%
info("Mica","Liang",27,"mango")
# Out:
# 'my full name is Mica Liang ,my age is 27 ,i like mango'

# %%
def square_value(num):
    """return the caculation result"""
    return num**2
print(square_value(2))
print(square_value(-6))
# Out:
# 4
# 36

# %%
def square_value(num):
    """return the caculation result"""
    return num**2
print(square_value(2))
print(square_value(-6))
# Out:
# 4
# 36

# %%
def area_info(long,wide,heiht):
    return long*wide*heiht
print(area_info(15,5,10))
# Out:
# 750

# %%
def get_formatted_name(first_name,last_name,middle_name=""):
    full_name=first_name + ' '+middle_name +' '+ last_name
    return full_name.title()
print(get_formatted_name("liang","mica"))
# Out:
# Liang  Mica

# %%
Ali_name=get_formatted_name("zhang","mhmd","ali")
print(Ali_name)
# Out:
# Zhang Ali Mhmd

# %% [markdown]
# # Return a dictionary

# %%
def build_person(first_name,last_name):
    person={'first':first_name,'last':last_name}
    return person
    
person=build_person("liang","mica")
print(person)
# Out:
# {'first': 'liang', 'last': 'mica'}

# %%
def namecity(first_name,last_name,country,gender):
    full_name=first_name +" " + last_name
    personai_info={'full_name':first_name +" " + last_name,'place':country,'M_or_W':gender}
    return personai_info
    
namecity("liang","mica","China","Female")
# Out:
# {'full_name': 'liang mica', 'place': 'China', 'M_or_W': 'Female'}

# %%
def city_info(country,city):
    visit={'country_name':country,'city_name':city}
    return visit

visit=city_info("China","GuangXi")
print(visit)
# Out:
# {'country_name': 'China', 'city_name': 'GuangXi'}

# %% [markdown]
# # Return a list

# %%
def my_function(food):
    for x in food:
        print(x)
fruits=["apple","banana","cherry"]
my_function(fruits)
# Out:
# apple
# banana
# cherry

# %%
meat=["beef","lamb","tofu","fish"]
my_function(meat)
# Out:
# beef
# lamb
# tofu
# fish

# %%
def mfunc(friends):
    for name in friends:
        print(name.title()+" is my best friend!")

my_friends=["andy","angle","rose","sofia"]
mfunc(my_friends)
# Out:
# Andy is my best friend!
# Angle is my best friend!
# Rose is my best friend!
# Sofia is my best friend!

# %%
def course(subjects):
    for course in subjects:
        print(course)

subjects=['data_science','mathmatics','english']
course(subjects)
# Out:
# data_science
# mathmatics
# english

# %%
def my_course(subjects):
    for course in subjects:
        print("I love studying "+course.upper()+" very much!")

course=['data_science','mathmatics','english']
my_course(course)
# Out:
# I love studying DATA_SCIENCE very much!
# I love studying MATHMATICS very much!
# I love studying ENGLISH very much!

# %% [markdown]
# # Passing multiple arguments(可多传参数)

# %%
def make_pizza(*toppings):
    print(toppings)

make_pizza("pepperoni")
make_pizza("smushroom","green peppers","extra cheese")
# Out:
# ('pepperoni',)
# ('smushroom', 'green peppers', 'extra cheese')

# %%
def make_pizza(size,*toppings):
    print("\nMaking a "+str(size)+"-inch pizza with the following toppings:")
    for topping in toppings:
        print("-"+topping)

make_pizza(16,"pepperoni")
make_pizza(20,"smushroom","green peppers","extra cheese")
# Out:
# Making a 16-inch pizza with the following toppings:
# -pepperoni
#
# Making a 20-inch pizza with the following toppings:
# -smushroom
# -green peppers
# -extra cheese

# %%
def myfun(name,*subjects):
    print(name.title()+":"+"Choose these subjects:")
    for subject in subjects:
        print("-"+subject)
myfun("mica","math","english","biology")
# Out:
# Mica:Choose these subjects:
# -math
# -english
# -biology

# %%
# dictionary(需要两颗**)
def build_profile(first,last,**user_info):
    profile={}
    profile['first_name']=first
    profile['last_name']=last
    for key,value in user_info.items():
        profile[key]=value
    return profile
user_profile=build_profile('albert','einstein',location='princeton',filed='physics')
print(user_profile)
# Out:
# {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'filed': 'physics'}

# %%
def car_info(first,last,gender,**car):
    detail={}
    detail["first_name"]=first
    detail["last_name"]=last
    detail["M_or_W"]=gender
    for key,value in car.items():
        car_detail[key]=value
    return car_detail
    
car_detail=car_info("sunny","Li","male",car1="Tesla",car2="BMW",car3="YAMAHA")
print(car_detail)
# Out:
# {'first_name': 'sunny', 'last_name': 'Li', 'M_or_W': 'male', 'car1': 'Tesla', 'car2': 'BMW', 'car3': 'YAMAHA'}

# %% [markdown]
# # CLASSES

# %%
class Person:
    def __init__(self,name,age):
     self.name=name
     self.age=age

p1=Person("John",36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
class Person:
    def __init__(self,name,age):
     self.name=name
     self.age=age
    def myfunc(self):
        print("Hello my name is "+self.name)

p1=Person("John",36)
p1.myfunc()
# Out:
# Hello my name is John

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
# Out:
# 2016 Audi A4

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
        
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# This car has 0 miles on it.

# %%
my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# This car has 23 miles on it.

# %%
class Car():
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
        
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print("This car has " + str(self.odometer_reading) + " miles on it.")
    
    def update_odometer(self, mileage):
        """Add the given amount to the odometer reading."""
        self.odometer_reading = mileage

# %%
my_used_car = Car('subaru', 'outback', 2013)
print(my_used_car.get_descriptive_name())
# Out:
# 2013 Subaru Outback

# %%
my_new_car.update_odometer(23)
my_new_car.read_odometer()
# Out:
# This car has 23 miles on it.

# %%
class Car():
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
        
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print("This car has " + str(self.odometer_reading) + " miles on it.")
    
    def update_odometer(self, mileage):
        """Add the given amount to the odometer reading."""
        self.odometer_reading = mileage
        
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += miles

# %%
my_used_car = Car('subaru', 'outback', 2013)
print(my_used_car.get_descriptive_name())
# Out:
# 2013 Subaru Outback

# %%
my_used_car.update_odometer(23500)
my_used_car.read_odometer()
# Out:
# This car has 23500 miles on it.

# %%
my_used_car.increment_odometer(100)
my_used_car.read_odometer()
# Out:
# This car has 23700 miles on it.

# %% [markdown]
# # INHERITANCE(继承)

# %%
class Car():
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
        
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print("This car has " + str(self.odometer_reading) + " miles on it.")
    
    def update_odometer(self, mileage):
        """Add the given amount to the odometer reading."""
        self.odometer_reading = mileage
        
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += miles

class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    def __init__(self, make, model, year):
        """Initialize attributes of the parent class."""
        super().__init__(make, model, year)

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
# Out:
# 2016 Tesla Model S

# %%
class Car():
    """A simple attempt to represent a car."""
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
        
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print("This car has " + str(self.odometer_reading) + " miles on it.")
    
    def update_odometer(self, mileage):
        """Add the given amount to the odometer reading."""
        self.odometer_reading = mileage
        
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += miles

class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    def __init__(self, make, model, year):
        """Initialize attributes of the parent class."""
        super().__init__(make, model, year)
        self.battery_size = 70
        
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
my_tesla.describe_battery()
# Out:
# 2016 Tesla Model S
# This car has a 70-kWh battery.
