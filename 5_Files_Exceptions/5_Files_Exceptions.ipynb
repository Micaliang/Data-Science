# %% [markdown]
# # reading file

# %%
# 方法1
with open('pi_digits.txt') as file_object:contents = file_object.read()
print(contents)
# Out:
# 3.1415926535
#  8979323846
#  2643383279

# %%
# 方法2
file_path='C:/Users/86150/Desktop/Course info/Semester_2/STQD6014_DATA_SCIENCE/5.Files  Exceptions/pi_digits.txt'
with open(file_path) as file_object:
    contents = file_object.read()
    print(contents)
# Out:
# 3.1415926535
#  8979323846
#  2643383279

# %%
# 方法3
filename='pi_digits.txt'
with open(file_path) as file_object:
    for line in file_object:
        print(line)
# Out:
# 3.1415926535
#
#  8979323846
#
#  2643383279

# %% [markdown]
# # writing file

# %%
# 方法1
filename='programming.txt'
with open(filename,'w') as file_object:
    file_object.write(" i love programing.\n")
    file_object.write("I love creating new games.\n")
    file_object.write("But it is very difficult.\n")
    file_object.write("But i need to learn.\n")

# %%
# 方法2
filename='programming.txt'
with open(filename,'a') as file_object:
     file_object.write("I also love finding meaning in large datasets.\n")
     file_object.write("I love creating apps that can run in a browser.\n")

# %% [markdown]
# # EXCEPTIONS

# %% [markdown]
# # ZeroDivisionError

# %%
try:
    print(5/0)

except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ")
    
    try:
        answer = int(first_number) / int(second_number) #the code
    except ZeroDivisionError:
        print("You can't divide by 0!") #print the error
    else:
        print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
# First number:  23
# Second number:  34
# 0.6764705882352942
# First number:  q

# %% [markdown]
# # FileNotFoundError

# %%
filename = 'alice.txt'

try:
    with open(filename) as f_obj: #the code for opening file
        contents = f_obj.read()
except FileNotFoundError:
    msg = "Sorry, the file " + filename + " does not exist."
    print(msg) #print the error
# Out:
# Sorry, the file alice.txt does not exist.

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ")
    if second_number == 'q':
        break
    answer = int(first_number) / int(second_number)
    print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
# First number:  12
# Second number:  12
# 1.0
# First number:  q

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ")
    try:
        answer = int(first_number) / int(second_number) #the code
    except ZeroDivisionError:
        print("You can't divide by 0!") #print the error
    else:
        print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
# First number:  12
# Second number:  0
# You can't divide by 0!
# First number:  q

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == 'q':
        break
    second_number = input("Second number: ") 
    
    try:
        answer = int(first_number) / int(second_number) 
    except ZeroDivisionError:
        pass
    else:
        print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
# First number:  12
# Second number:  12
# 1.0
# First number:  q

# %% [markdown]
# # json

# %%
import json
numbers = [2, 3, 5, 7, 11, 13]
filename = 'numbers.json'
with open(filename, 'w') as f_obj:
    json.dump(numbers, f_obj)

print(numbers)
# Out:
# [2, 3, 5, 7, 11, 13]
