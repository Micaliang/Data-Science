# %%
print("Hello python world!")
# Out:
# Hello python world!

# %%
2==3
# Out:
# False

# %%
2+3
# Out:
# 5

# %%
name="Mica"
age=12
gpa=3.73
is_student=True

# %%
print(name)
# Out:
# Mica

# %%
print(age)
# Out:
# 12

# %%
print(gpa)
# Out:
# 3.73

# %%
print(is_student)
# Out:
# True

# %%
num=18

# %%
print(int(num))
# Out:
# 18

# %%
print(float(num))
# Out:
# 18.0

# %%
name=input("Your name:")
print("Hello " + name + ", welcome to python word!")
# Out:
# Your name: Mica
# Hello Mica, welcome to python word!

# %%
sentence = "i love python programming"
print(sentence.title())
print(sentence.lower())
print(sentence.upper())
# Out:
# I Love Python Programming
# i love python programming
# I LOVE PYTHON PROGRAMMING

# %%
major = "Data Science"
uni = "UKM"
print("My major is " +major)
print("I study at "+uni)
# Out:
# My major is Data Science
# I study at UKM

# %%
pages=input()
count=(int(pages)+4)//5
print("Need "+str(count)+" pages' stemps.")
# Out:
#  20
# Need 4 pages' stemps.

# %%
num=input()
if int(num)%2==0:
    print("Eastbound")
else:
    print("Westbound")
# Out:
#  8
# Eastbound

# %%
scores=[80,90,75,85,95]
total=(sum(scores))
count=len(scores)
average=total/count
print("总分:" + str(total)+","+" 人数："+str(count)+", 平均分："+str(average))
# Out:
# 总分:425, 人数：5, 平均分：85.0

# %%
height=float(input("Your height is(m):"))
h=height*100
print("Your height is:"+str(h)+"cm.")
# Out:
# Your height is(m): 1.68
# Your height is:168.0cm.

# %%
name=input("Please input your name:")
age=input("Please input your age:")
major=input("Please input your major:")
print("======info======")
print("Name:"+name)
print("Age:"+age)
print("Major:"+major)
print("================")
# Out:
# Please input your name: Mica
# Please input your age: 23
# Please input your major: DS
# ======info======
# Name:Mica
# Age:23
# Major:DS
# ...
