# %%
# 导入整个module，需要module.function_name(信息)才能引用
# import module_name
# module_name.function_name()
import Crash_module

# %%
Crash_module.make_car('subaru', 'outback', color='blue', tow_package=True)
# Out:
# {'manufacturer': 'subaru',
#  'model': 'outback',
#  'color': 'blue',
#  'tow_package': True}

# %%
Crash_module.make_pizza(16, 'green peppers', 'extra cheese')
# Out:
# Making a 16-inch pizza witn the following toppings:
# - green peppers
# - extra cheese

# %%
# 导入整个module 到简写Cm，方便引用
# import module_name as mn
import Crash_module as Cm

# %%
Cm.make_car('subaru', 'outback', color='blue', tow_package=True)
# Out:
# {'manufacturer': 'subaru',
#  'model': 'outback',
#  'color': 'blue',
#  'tow_package': True}

# %%
Cm.sandwich('egg','mango','watermelon')
# Out:
#  Making a andwich witn the following toppings:
# - egg
# - mango
# - watermelon

# %%
# 从 module 中导入某个function
# from module_name import function_name

# %%
from Crash_module import show_magicians

# %%
magicians = ['mica','anna','jessica']

make_great(magicians)
show_magicians(magicians)
# Out:
# The Great Mica
# The Great Anna
# The Great Jessica

# %%
# 从module 单独导入某个function,注意function name 不要加()
# from module_name import function_name as fn

# %%
from Crash_module import make_car as mc

# %%
mc('subaru', 'outback', color='blue', tow_package=True)
# Out:
# {'manufacturer': 'subaru',
#  'model': 'outback',
#  'color': 'blue',
#  'tow_package': True}

# %%
# 导入整个module的所有function
# from module_name import *
from Crash_module import *

# %%
magicians = ['mica','anna','jessica']

make_great(magicians)
show_magicians(magicians)
# Out:
# The Great Mica
# The Great Anna
# The Great Jessica

# %%
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pepperoni-inch pizza witn the following toppings:
#
# Making a mushrooms-inch pizza witn the following toppings:
# - green peppers
# - extra cheese
