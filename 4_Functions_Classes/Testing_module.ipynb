# %%
# 方法1
import module

# %%
module.make_pizza(16,"mushroom")
# Out:
# Making a 16-inch pizza with the following toppings:
# -mushroom

# %%
module.make_pizza(20,"smushroom","green peppers","extra cheese")
# Out:
# Making a 20-inch pizza with the following toppings:
# -smushroom
# -green peppers
# -extra cheese

# %%
module.nameAge("mica",34)
# Out:
# Hi,I am mica
# My age is 34

# %%
# 方法2
import module as m

# %%
m.nameAge("Sara",23)
# Out:
# Hi,I am Sara
# My age is 23

# %%
# 方法3
from module import nameAge

# %%
nameAge("Sara",23)
# Out:
# Hi,I am Sara
# My age is 23

# %%
from module import make_pizza,nameAge

# %%
make_pizza(20,"smushroom","green peppers","extra cheese")
# Out:
# Making a 20-inch pizza with the following toppings:
# -smushroom
# -green peppers
# -extra cheese

# %%
nameAge("Wenda",30)
# Out:
# Hi,I am Wenda
# My age is 30

# %%
# 方法4
from module import *

# %%
nameAge("Tina",18)
# Out:
# Hi,I am Tina
# My age is 18

# %%
make_pizza(16,"vegetable","beef","lamb")
# Out:
# Making a 16-inch pizza with the following toppings:
# -vegetable
# -beef
# -lamb

# %% [markdown]
# # Vehicle

# %%
from Vehicle import *

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
# Out:
# 2016 Tesla Model S

# %%
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
my_tesla.describe_battery()
# Out:
# 2016 Tesla Model S
# This car has a 70-kWh battery.

# %%
my_tesla = ElectricCar('XIAOMI', 'm5', 2026)
print(my_tesla.get_descriptive_name())
my_tesla.describe_battery()
# Out:
# 2026 Xiaomi M5
# This car has a 70-kWh battery.
